# %%
import pandas as pd

# %% [markdown]
# ## Subprogram

# %%
def dfToDictionary(df):
  ''' Fungsi untuk membuat dictionary dari dataframe '''
  dictDf = {}
  for idx in range(len(df.index)):
    id = df.loc[idx]['id']
    # Buat Dictionary per ID
    dictDf[id] = {}
    dictDf[id]['servis'] = df.loc[idx]['servis']
    dictDf[id]['harga'] = df.loc[idx]['harga']

  return dictDf

# %%
''' ==== FUZZIFICATION ==== '''

def fuzzificationMain(bengkelDict):
  ''' Fungsi untuk mengembalikan nilai fuzzy dari dataset '''
  dictFuzzyBengkel = {}
  for key in bengkelDict:
    x = bengkelDict[key]['servis']
    y = bengkelDict[key]['harga']

    # Make dictionary for fuzzy
    dictFuzzyBengkel[key] = {}
    dictFuzzyBengkel[key]['servis'] = {}
    dictFuzzyBengkel[key]['harga'] = {}

    # Fuzzy servis dan harga
    dictFuzzyBengkel = fuzzificationServis(dictFuzzyBengkel, key, x)
    dictFuzzyBengkel = fuzzificationHarga(dictFuzzyBengkel, key, y)

  return dictFuzzyBengkel

def fuzzificationServis(fuzzyDict, key, x): # Rapli
  ''' Mengembalikan nilai fuzzy dari crisp input servis '''
  # Buruk
  if x <= 50:
    fuzzyDict[key]['servis']['Buruk'] = 1
  elif 50 < x < 60:
    fuzzyDict[key]['servis']['Buruk'] = -(x - 60) / (60 - 50)
  elif x >= 60:
    fuzzyDict[key]['servis']['Buruk'] = 0

  # Lumayan
  if x <= 50 or x >= 75:
    fuzzyDict[key]['servis']['Lumayan'] = 0
  elif 50 < x < 60:
    fuzzyDict[key]['servis']['Lumayan'] = (x - 50) / (60 - 50)
  elif 60 <= x <= 70:
    fuzzyDict[key]['servis']['Lumayan'] = 1
  elif 70 < x < 75:
    fuzzyDict[key]['servis']['Lumayan'] = -(x - 75) / (75 - 70)

  # Baik
  if x <= 70 or x >= 90:
    fuzzyDict[key]['servis']['Baik'] = 0
  if 70 < x < 75:
    fuzzyDict[key]['servis']['Baik'] = (x - 70) / (75 - 70)
  if 75 <= x <= 85:
    fuzzyDict[key]['servis']['Baik'] = 1
  if 85 < x < 90:
    fuzzyDict[key]['servis']['Baik'] = -(x - 90) / (90 - 85)

  # Sangat Baik
  if x <= 85:
    fuzzyDict[key]['servis']['Sangat Baik'] = 0
  if 85 < x < 90:
    fuzzyDict[key]['servis']['Sangat Baik'] = (x - 85) / (90 - 85)
  if x >= 90:
    fuzzyDict[key]['servis']['Sangat Baik'] = 1

  return fuzzyDict

def fuzzificationHarga(fuzzyDict, key, y): # Hapian
  ''' Mengembalikan nilai fuzzy dari crisp input harga '''
  # Murah 0 - 3 - 5
  if y <= 3:
    fuzzyDict[key]['harga']['Murah'] = 1
  elif 3 < y < 5:
    fuzzyDict[key]['harga']['Murah'] = -(y - 5) / (5 - 3)
  elif y >= 5:
    fuzzyDict[key]['harga']['Murah'] = 0


  # Sedang 3 - 5 - 8
  if y <= 3 or y >= 8:
    fuzzyDict[key]['harga']['Sedang'] = 0
  elif 3 < y < 5:
    fuzzyDict[key]['harga']['Sedang'] = (y - 3) / (5 - 3)
  elif 5 <= y <= 6:
    fuzzyDict[key]['harga']['Sedang'] = 1
  elif 6 < y < 8:
    fuzzyDict[key]['harga']['Sedang'] = -(y - 8) / (8 - 6)


  # Mahal 6 - 8 - 10
  if y <= 6:
    fuzzyDict[key]['harga']['Mahal'] = 0
  if 6 < y < 8:
    fuzzyDict[key]['harga']['Mahal'] = (y - 6) / (8 - 6)
  if y >= 8:
    fuzzyDict[key]['harga']['Mahal'] = 1

  return fuzzyDict

# Example Hasil:
#  {1: {'harga': {'Mahal': 0.5, 'Murah': 0, 'Sedang': 0.5},
#    'servis': {'Baik': 0, 'Buruk': 0.2, 'Lumayan': 0.8, 'Sangat Baik': 0}},
#  2: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#    'servis': {'Baik': 0, 'Buruk': 0.6, 'Lumayan': 0.4, 'Sangat Baik': 0}},

# %%
''' ==== INFERENCE ==== '''

def inferenceMain(fuzziedDict):
  ''' Mengembalikan hasil inferensi dari nilai fuzzy harga dan servis yang dipunya '''
  # Buat Dictionary untuk hasil inferensi
  dictInferenced = {}
  for id in fuzziedDict:
    dictInferenced[id] = {}

    # List untuk nampung value hasil inference per bengkel
    listBuruk = []
    listBiasaAja = []
    listRecommended = []

    for varHarga, valueHarga in fuzziedDict[id]['harga'].items():
      for varServis, valueServis in fuzziedDict[id]['servis'].items():
        minAnd = min(valueHarga, valueServis)
        score = inferenceTable(varServis, varHarga)

        # Append ke List untuk nanti di max() / or
        if score == 'Buruk':
          listBuruk.append(minAnd)
        elif score == 'B aja':
          listBiasaAja.append(minAnd)
        elif score == 'Recommended':
          listRecommended.append(minAnd)

    dictInferenced[id]['Buruk'] = max(listBuruk)
    dictInferenced[id]['B aja'] = max(listBiasaAja)
    dictInferenced[id]['Recommended'] = max(listRecommended)

  return dictInferenced

# Example Dictionary Inference yang Udah Jadi
# {1 : {'Buruk' : 0, 'B aja' : 0, 'Recommended' : 0},
# 2 : {'Buruk' : 0, 'B aja' : 0, 'Recommended' : 0}}

def inferenceTable(keyServis, keyHarga):
  if keyServis == 'Buruk':
    if keyHarga == 'Murah':
      hasil = 'Buruk'
    elif keyHarga == 'Sedang':
      hasil = 'Buruk'
    elif keyHarga == 'Mahal':
      hasil = 'Buruk'

  elif keyServis == 'Lumayan':
    if keyHarga == 'Murah':
      hasil = 'B aja'
    elif keyHarga == 'Sedang':
      hasil = 'B aja'
    elif keyHarga == 'Mahal':
      hasil = 'Buruk'

  elif keyServis == 'Baik':
    if keyHarga == 'Murah':
      hasil = 'Recommended'
    elif keyHarga == 'Sedang':
      hasil = 'Recommended'
    elif keyHarga == 'Mahal':
      hasil = 'B aja'

  elif keyServis == 'Sangat Baik':
    if keyHarga == 'Murah':
      hasil = 'Recommended'
    elif keyHarga == 'Sedang':
      hasil = 'Recommended'
    elif keyHarga == 'Mahal':
      hasil = 'Recommended'

  return hasil

# %%
def defuzziSugeno(inferencedDataset):
  ''' Mengembalikan nilai hasil deffuzification menggunakan metode sugeno '''
  dictdefuzied = {}
  for id in inferencedDataset:
    hasil = (inferencedDataset[id]['B aja']*70) + (inferencedDataset[id]['Buruk']*50) + (inferencedDataset[id]['Recommended']*100)
    pembagi = inferencedDataset[id]['B aja'] + inferencedDataset[id]['Buruk'] + inferencedDataset[id]['Recommended']
    defuzzi = hasil/pembagi
    dictdefuzied[id] = defuzzi

  return dictdefuzied

# Example Output
# id bengkel : hasil defuzzi
# {1 : 50,
#  2 : 10,
#  3 : 90}

# %%
def makeDataframeTopTen(sortedDataset):
  ''' Fungsi untuk mengembalikan dataframe dari dataset yang sudah di sort '''
  listID = []
  listScore = []
  for i in range(len(sortedDataset)):
    listID.append(sortedDataset[i][0])
    listScore.append(sortedDataset[i][1])

  final = zip(listID, listScore)
  dfFinal = pd.DataFrame(final, columns = ["ID", "Hasil"])

  return dfFinal

# %% [markdown]
# ## Preparation

# %%
# Download Dataset
# !gdown --id "1XGEMtjvPF2PUV0Mwklnpk0Ev9AwJitFq"
# Out:
# /usr/local/lib/python3.7/dist-packages/gdown/cli.py:131: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   category=FutureWarning,
# Downloading...
# From: https://drive.google.com/uc?id=1XGEMtjvPF2PUV0Mwklnpk0Ev9AwJitFq
# To: /content/bengkel.xlsx
# 100% 16.9k/16.9k [00:00<00:00, 22.3MB/s]

# %%
# Membaca file excel
bengkelDf = pd.read_excel('bengkel.xlsx')
bengkelDf
# Out:
#      id  servis  harga
# 0     1      58      7
# 1     2      54      1
# 2     3      98      2
# 3     4      52      4
# 4     5      11      4
# ..  ...     ...    ...
# 95   96      30      1
# 96   97      25      3
# 97   98      27     10
# 98   99       8      6
# 99  100      11      8
#
# [100 rows x 3 columns]

# %%
# Mengubah dataframe menjadi dictionary
dictBengkel = dfToDictionary(bengkelDf)
dictBengkel
# Out:
# {1: {'harga': 7, 'servis': 58},
#  2: {'harga': 1, 'servis': 54},
#  3: {'harga': 2, 'servis': 98},
#  4: {'harga': 4, 'servis': 52},
#  5: {'harga': 4, 'servis': 11},
#  6: {'harga': 10, 'servis': 59},
#  7: {'harga': 8, 'servis': 61},
#  8: {'harga': 10, 'servis': 30},
#  9: {'harga': 1, 'servis': 45},
#  10: {'harga': 9, 'servis': 36},
#  11: {'harga': 5, 'servis': 10},
#  12: {'harga': 7, 'servis': 38},
#  13: {'harga': 3, 'servis': 80},
#  14: {'harga': 8, 'servis': 31},
#  15: {'harga': 5, 'servis': 78},
#  16: {'harga': 6, 'servis': 82},
#  17: {'harga': 3, 'servis': 70},
#  18: {'harga': 9, 'servis': 3},
#  19: {'harga': 3, 'servis': 42},
#  20: {'harga': 10, 'servis': 49},
#  21: {'harga': 2, 'servis': 48},
#  22: {'harga': 9, 'servis': 79},
#  23: {'harga': 4, 'servis': 18},
#  24: {'harga': 9, 'servis': 100},
#  25: {'harga': 10, 'servis': 61},
#  26: {'harga': 2, 'servis': 4},
#  27: {'harga': 8, 'servis': 59},
#  28: {'harga': 3, 'servis': 44},
#  29: {'harga': 8, 'servis': 11},
#  30: {'harga': 6, 'servis': 7},
#  31: {'harga': 9, 'servis': 74},
#  32: {'harga': 3, 'servis': 42},
#  33: {'harga': 8, 'servis': 33},
#  34: {'harga': 4, 'servis': 93},
#  35: {'harga': 1, 'servis': 4},
#  36: {'harga': 6, 'servis': 32},
#  37: {'harga': 4, 'servis': 31},
#  38: {'harga': 1, 'servis': 10},
#  39: {'harga': 7, 'servis': 52},
#  40: {'harga': 6, 'servis': 7},
#  41: {'harga': 2, 'servis': 33},
#  42: {'harga': 10, 'servis': 94},
#  43: {'harga': 3, 'servis': 34},
#  44: {'harga': 2, 'servis': 63},
#  45: {'harga': 8, 'servis': 3},
#  46: {'harga': 1, 'servis': 38},
#  47: {'harga': 3, 'servis': 21},
#  48: {'harga': 4, 'servis': 64},
#  49: {'harga': 1, 'servis': 19},
#  50: {'harga': 5, 'servis': 42},
#  51: {'harga': 10, 'servis': 48},
#  52: {'harga': 3, 'servis': 94},
#  53: {'harga': 6, 'servis': 21},
#  54: {'harga': 10, 'servis': 64},
#  55: {'harga': 7, 'servis': 50},
#  56: {'harga': 3, 'servis': 49},
#  57: {'harga': 3, 'servis': 24},
#  58: {'harga': 1, 'servis': 31},
#  59: {'harga': 4, 'servis': 28},
#  60: {'harga': 6, 'servis': 79},
#  61: {'harga': 4, 'servis': 42},
#  62: {'harga': 7, 'servis': 31},
#  63: {'harga': 7, 'servis': 78},
#  64: {'harga': 2, 'servis': 35},
#  65: {'harga': 8, 'servis': 3},
#  66: {'harga': 9, 'servis': 4},
#  67: {'harga': 4, 'servis': 27},
#  68: {'harga': 5, 'servis': 59},
#  69: {'harga': 10, 'servis': 86},
#  70: {'harga': 8, 'servis': 78},
#  71: {'harga': 3, 'servis': 39},
#  72: {'harga': 6, 'servis': 26},
#  73: {'harga': 10, 'servis': 22},
#  74: {'harga': 4, 'servis': 54},
#  75: {'harga': 1, 'servis': 61},
#  76: {'harga': 5, 'servis': 45},
#  77: {'harga': 10, 'servis': 11},
#  78: {'harga': 1, 'servis': 20},
#  79: {'harga': 9, 'servis': 87},
#  80: {'harga': 10, 'servis': 39},
#  81: {'harga': 10, 'servis': 4},
#  82: {'harga': 4, 'servis': 13},
#  83: {'harga': 8, 'servis': 69},
#  84: {'harga': 2, 'servis': 11},
#  85: {'harga': 4, 'servis': 18},
#  86: {'harga': 5, 'servis': 30},
#  87: {'harga': 4, 'servis': 56},
#  88: {'harga': 9, 'servis': 18},
#  89: {'harga': 2, 'servis': 48},
#  90: {'harga': 1, 'servis': 10},
#  91: {'harga': 3, 'servis': 98},
#  92: {'harga': 3, 'servis': 83},
#  93: {'harga': 8, 'servis': 40},
#  94: {'harga': 3, 'servis': 20},
#  95: {'harga': 8, 'servis': 63},
#  96: {'harga': 1, 'servis': 30},
#  97: {'harga': 3, 'servis': 25},
#  98: {'harga': 10, 'servis': 27},
#  99: {'harga': 6, 'servis': 8},
#  100: {'harga': 8, 'servis': 11}}

# %% [markdown]
# ## Main

# %%
# Fuzziffication Dataset
fuzziedDataset = fuzzificationMain(dictBengkel)
fuzziedDataset
# Out:
# {1: {'harga': {'Mahal': 0.5, 'Murah': 0, 'Sedang': 0.5},
#   'servis': {'Baik': 0, 'Buruk': 0.2, 'Lumayan': 0.8, 'Sangat Baik': 0}},
#  2: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 0.6, 'Lumayan': 0.4, 'Sangat Baik': 0}},
#  3: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 0, 'Lumayan': 0, 'Sangat Baik': 1}},
#  4: {'harga': {'Mahal': 0, 'Murah': 0.5, 'Sedang': 0.5},
#   'servis': {'Baik': 0, 'Buruk': 0.8, 'Lumayan': 0.2, 'Sangat Baik': 0}},
#  5: {'harga': {'Mahal': 0, 'Murah': 0.5, 'Sedang': 0.5},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  6: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 0.1, 'Lumayan': 0.9, 'Sangat Baik': 0}},
#  7: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 0, 'Lumayan': 1, 'Sangat Baik': 0}},
#  8: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  9: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  10: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  11: {'harga': {'Mahal': 0, 'Murah': 0, 'Sedang': 1},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  12: {'harga': {'Mahal': 0.5, 'Murah': 0, 'Sedang': 0.5},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  13: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 1, 'Buruk': 0, 'Lumayan': 0, 'Sangat Baik': 0}},
#  14: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  15: {'harga': {'Mahal': 0, 'Murah': 0, 'Sedang': 1},
#   'servis': {'Baik': 1, 'Buruk': 0, 'Lumayan': 0, 'Sangat Baik': 0}},
#  16: {'harga': {'Mahal': 0, 'Murah': 0, 'Sedang': 1},
#   'servis': {'Baik': 1, 'Buruk': 0, 'Lumayan': 0, 'Sangat Baik': 0}},
#  17: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 0, 'Lumayan': 1, 'Sangat Baik': 0}},
#  18: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  19: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  20: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  21: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  22: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 1, 'Buruk': 0, 'Lumayan': 0, 'Sangat Baik': 0}},
#  23: {'harga': {'Mahal': 0, 'Murah': 0.5, 'Sedang': 0.5},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  24: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 0, 'Lumayan': 0, 'Sangat Baik': 1}},
#  25: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 0, 'Lumayan': 1, 'Sangat Baik': 0}},
#  26: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  27: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 0.1, 'Lumayan': 0.9, 'Sangat Baik': 0}},
#  28: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  29: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  30: {'harga': {'Mahal': 0, 'Murah': 0, 'Sedang': 1},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  31: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0.8, 'Buruk': 0, 'Lumayan': 0.2, 'Sangat Baik': 0}},
#  32: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  33: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  34: {'harga': {'Mahal': 0, 'Murah': 0.5, 'Sedang': 0.5},
#   'servis': {'Baik': 0, 'Buruk': 0, 'Lumayan': 0, 'Sangat Baik': 1}},
#  35: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  36: {'harga': {'Mahal': 0, 'Murah': 0, 'Sedang': 1},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  37: {'harga': {'Mahal': 0, 'Murah': 0.5, 'Sedang': 0.5},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  38: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  39: {'harga': {'Mahal': 0.5, 'Murah': 0, 'Sedang': 0.5},
#   'servis': {'Baik': 0, 'Buruk': 0.8, 'Lumayan': 0.2, 'Sangat Baik': 0}},
#  40: {'harga': {'Mahal': 0, 'Murah': 0, 'Sedang': 1},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  41: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  42: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 0, 'Lumayan': 0, 'Sangat Baik': 1}},
#  43: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  44: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 0, 'Lumayan': 1, 'Sangat Baik': 0}},
#  45: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  46: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  47: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  48: {'harga': {'Mahal': 0, 'Murah': 0.5, 'Sedang': 0.5},
#   'servis': {'Baik': 0, 'Buruk': 0, 'Lumayan': 1, 'Sangat Baik': 0}},
#  49: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  50: {'harga': {'Mahal': 0, 'Murah': 0, 'Sedang': 1},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  51: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  52: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 0, 'Lumayan': 0, 'Sangat Baik': 1}},
#  53: {'harga': {'Mahal': 0, 'Murah': 0, 'Sedang': 1},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  54: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 0, 'Lumayan': 1, 'Sangat Baik': 0}},
#  55: {'harga': {'Mahal': 0.5, 'Murah': 0, 'Sedang': 0.5},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  56: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  57: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  58: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  59: {'harga': {'Mahal': 0, 'Murah': 0.5, 'Sedang': 0.5},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  60: {'harga': {'Mahal': 0, 'Murah': 0, 'Sedang': 1},
#   'servis': {'Baik': 1, 'Buruk': 0, 'Lumayan': 0, 'Sangat Baik': 0}},
#  61: {'harga': {'Mahal': 0, 'Murah': 0.5, 'Sedang': 0.5},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  62: {'harga': {'Mahal': 0.5, 'Murah': 0, 'Sedang': 0.5},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  63: {'harga': {'Mahal': 0.5, 'Murah': 0, 'Sedang': 0.5},
#   'servis': {'Baik': 1, 'Buruk': 0, 'Lumayan': 0, 'Sangat Baik': 0}},
#  64: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  65: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  66: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  67: {'harga': {'Mahal': 0, 'Murah': 0.5, 'Sedang': 0.5},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  68: {'harga': {'Mahal': 0, 'Murah': 0, 'Sedang': 1},
#   'servis': {'Baik': 0, 'Buruk': 0.1, 'Lumayan': 0.9, 'Sangat Baik': 0}},
#  69: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0.8, 'Buruk': 0, 'Lumayan': 0, 'Sangat Baik': 0.2}},
#  70: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 1, 'Buruk': 0, 'Lumayan': 0, 'Sangat Baik': 0}},
#  71: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  72: {'harga': {'Mahal': 0, 'Murah': 0, 'Sedang': 1},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  73: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  74: {'harga': {'Mahal': 0, 'Murah': 0.5, 'Sedang': 0.5},
#   'servis': {'Baik': 0, 'Buruk': 0.6, 'Lumayan': 0.4, 'Sangat Baik': 0}},
#  75: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 0, 'Lumayan': 1, 'Sangat Baik': 0}},
#  76: {'harga': {'Mahal': 0, 'Murah': 0, 'Sedang': 1},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  77: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  78: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  79: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0.6, 'Buruk': 0, 'Lumayan': 0, 'Sangat Baik': 0.4}},
#  80: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  81: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  82: {'harga': {'Mahal': 0, 'Murah': 0.5, 'Sedang': 0.5},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  83: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 0, 'Lumayan': 1, 'Sangat Baik': 0}},
#  84: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  85: {'harga': {'Mahal': 0, 'Murah': 0.5, 'Sedang': 0.5},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  86: {'harga': {'Mahal': 0, 'Murah': 0, 'Sedang': 1},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  87: {'harga': {'Mahal': 0, 'Murah': 0.5, 'Sedang': 0.5},
#   'servis': {'Baik': 0, 'Buruk': 0.4, 'Lumayan': 0.6, 'Sangat Baik': 0}},
#  88: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  89: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  90: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  91: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 0, 'Lumayan': 0, 'Sangat Baik': 1}},
#  92: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 1, 'Buruk': 0, 'Lumayan': 0, 'Sangat Baik': 0}},
#  93: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  94: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  95: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 0, 'Lumayan': 1, 'Sangat Baik': 0}},
#  96: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  97: {'harga': {'Mahal': 0, 'Murah': 1, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  98: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  99: {'harga': {'Mahal': 0, 'Murah': 0, 'Sedang': 1},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}},
#  100: {'harga': {'Mahal': 1, 'Murah': 0, 'Sedang': 0},
#   'servis': {'Baik': 0, 'Buruk': 1, 'Lumayan': 0, 'Sangat Baik': 0}}}

# %%
# Inference Dataset
inferencedDataset = inferenceMain(fuzziedDataset)
inferencedDataset
# Out:
# {1: {'B aja': 0.5, 'Buruk': 0.5, 'Recommended': 0},
#  2: {'B aja': 0.4, 'Buruk': 0.6, 'Recommended': 0},
#  3: {'B aja': 0, 'Buruk': 0, 'Recommended': 1},
#  4: {'B aja': 0.2, 'Buruk': 0.5, 'Recommended': 0},
#  5: {'B aja': 0, 'Buruk': 0.5, 'Recommended': 0},
#  6: {'B aja': 0, 'Buruk': 0.9, 'Recommended': 0},
#  7: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  8: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  9: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  10: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  11: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  12: {'B aja': 0, 'Buruk': 0.5, 'Recommended': 0},
#  13: {'B aja': 0, 'Buruk': 0, 'Recommended': 1},
#  14: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  15: {'B aja': 0, 'Buruk': 0, 'Recommended': 1},
#  16: {'B aja': 0, 'Buruk': 0, 'Recommended': 1},
#  17: {'B aja': 1, 'Buruk': 0, 'Recommended': 0},
#  18: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  19: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  20: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  21: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  22: {'B aja': 1, 'Buruk': 0, 'Recommended': 0},
#  23: {'B aja': 0, 'Buruk': 0.5, 'Recommended': 0},
#  24: {'B aja': 0, 'Buruk': 0, 'Recommended': 1},
#  25: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  26: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  27: {'B aja': 0, 'Buruk': 0.9, 'Recommended': 0},
#  28: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  29: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  30: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  31: {'B aja': 0.8, 'Buruk': 0.2, 'Recommended': 0},
#  32: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  33: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  34: {'B aja': 0, 'Buruk': 0, 'Recommended': 0.5},
#  35: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  36: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  37: {'B aja': 0, 'Buruk': 0.5, 'Recommended': 0},
#  38: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  39: {'B aja': 0.2, 'Buruk': 0.5, 'Recommended': 0},
#  40: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  41: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  42: {'B aja': 0, 'Buruk': 0, 'Recommended': 1},
#  43: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  44: {'B aja': 1, 'Buruk': 0, 'Recommended': 0},
#  45: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  46: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  47: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  48: {'B aja': 0.5, 'Buruk': 0, 'Recommended': 0},
#  49: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  50: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  51: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  52: {'B aja': 0, 'Buruk': 0, 'Recommended': 1},
#  53: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  54: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  55: {'B aja': 0, 'Buruk': 0.5, 'Recommended': 0},
#  56: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  57: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  58: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  59: {'B aja': 0, 'Buruk': 0.5, 'Recommended': 0},
#  60: {'B aja': 0, 'Buruk': 0, 'Recommended': 1},
#  61: {'B aja': 0, 'Buruk': 0.5, 'Recommended': 0},
#  62: {'B aja': 0, 'Buruk': 0.5, 'Recommended': 0},
#  63: {'B aja': 0.5, 'Buruk': 0, 'Recommended': 0.5},
#  64: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  65: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  66: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  67: {'B aja': 0, 'Buruk': 0.5, 'Recommended': 0},
#  68: {'B aja': 0.9, 'Buruk': 0.1, 'Recommended': 0},
#  69: {'B aja': 0.8, 'Buruk': 0, 'Recommended': 0.2},
#  70: {'B aja': 1, 'Buruk': 0, 'Recommended': 0},
#  71: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  72: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  73: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  74: {'B aja': 0.4, 'Buruk': 0.5, 'Recommended': 0},
#  75: {'B aja': 1, 'Buruk': 0, 'Recommended': 0},
#  76: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  77: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  78: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  79: {'B aja': 0.6, 'Buruk': 0, 'Recommended': 0.4},
#  80: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  81: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  82: {'B aja': 0, 'Buruk': 0.5, 'Recommended': 0},
#  83: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  84: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  85: {'B aja': 0, 'Buruk': 0.5, 'Recommended': 0},
#  86: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  87: {'B aja': 0.5, 'Buruk': 0.4, 'Recommended': 0},
#  88: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  89: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  90: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  91: {'B aja': 0, 'Buruk': 0, 'Recommended': 1},
#  92: {'B aja': 0, 'Buruk': 0, 'Recommended': 1},
#  93: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  94: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  95: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  96: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  97: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  98: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  99: {'B aja': 0, 'Buruk': 1, 'Recommended': 0},
#  100: {'B aja': 0, 'Buruk': 1, 'Recommended': 0}}

# %%
# Defuzzification Dataset
defuziedDataset = defuzziSugeno(inferencedDataset)
defuziedDataset
# Out:
# {1: 60.0,
#  2: 58.0,
#  3: 100.0,
#  4: 55.714285714285715,
#  5: 50.0,
#  6: 50.0,
#  7: 50.0,
#  8: 50.0,
#  9: 50.0,
#  10: 50.0,
#  11: 50.0,
#  12: 50.0,
#  13: 100.0,
#  14: 50.0,
#  15: 100.0,
#  16: 100.0,
#  17: 70.0,
#  18: 50.0,
#  19: 50.0,
#  20: 50.0,
#  21: 50.0,
#  22: 70.0,
#  23: 50.0,
#  24: 100.0,
#  25: 50.0,
#  26: 50.0,
#  27: 50.0,
#  28: 50.0,
#  29: 50.0,
#  30: 50.0,
#  31: 66.0,
#  32: 50.0,
#  33: 50.0,
#  34: 100.0,
#  35: 50.0,
#  36: 50.0,
#  37: 50.0,
#  38: 50.0,
#  39: 55.714285714285715,
#  40: 50.0,
#  41: 50.0,
#  42: 100.0,
#  43: 50.0,
#  44: 70.0,
#  45: 50.0,
#  46: 50.0,
#  47: 50.0,
#  48: 70.0,
#  49: 50.0,
#  50: 50.0,
#  51: 50.0,
#  52: 100.0,
#  53: 50.0,
#  54: 50.0,
#  55: 50.0,
#  56: 50.0,
#  57: 50.0,
#  58: 50.0,
#  59: 50.0,
#  60: 100.0,
#  61: 50.0,
#  62: 50.0,
#  63: 85.0,
#  64: 50.0,
#  65: 50.0,
#  66: 50.0,
#  67: 50.0,
#  68: 68.0,
#  69: 76.0,
#  70: 70.0,
#  71: 50.0,
#  72: 50.0,
#  73: 50.0,
#  74: 58.888888888888886,
#  75: 70.0,
#  76: 50.0,
#  77: 50.0,
#  78: 50.0,
#  79: 82.0,
#  80: 50.0,
#  81: 50.0,
#  82: 50.0,
#  83: 50.0,
#  84: 50.0,
#  85: 50.0,
#  86: 50.0,
#  87: 61.11111111111111,
#  88: 50.0,
#  89: 50.0,
#  90: 50.0,
#  91: 100.0,
#  92: 100.0,
#  93: 50.0,
#  94: 50.0,
#  95: 50.0,
#  96: 50.0,
#  97: 50.0,
#  98: 50.0,
#  99: 50.0,
#  100: 50.0}

# %%
# Menyortir hasil defuzzification menjadi descending berdasarkan value
sortedDefuziedDataset = sorted(defuziedDataset.items(), key=lambda item: item[1], reverse=True)
sortedDefuziedDataset
# Out:
# [(3, 100.0),
#  (13, 100.0),
#  (15, 100.0),
#  (16, 100.0),
#  (24, 100.0),
#  (34, 100.0),
#  (42, 100.0),
#  (52, 100.0),
#  (60, 100.0),
#  (91, 100.0),
#  (92, 100.0),
#  (63, 85.0),
#  (79, 82.0),
#  (69, 76.0),
#  (17, 70.0),
#  (22, 70.0),
#  (44, 70.0),
#  (48, 70.0),
#  (70, 70.0),
#  (75, 70.0),
#  (68, 68.0),
#  (31, 66.0),
#  (87, 61.11111111111111),
#  (1, 60.0),
#  (74, 58.888888888888886),
#  (2, 58.0),
#  (4, 55.714285714285715),
#  (39, 55.714285714285715),
#  (5, 50.0),
#  (6, 50.0),
#  (7, 50.0),
#  (8, 50.0),
#  (9, 50.0),
#  (10, 50.0),
#  (11, 50.0),
#  (12, 50.0),
#  (14, 50.0),
#  (18, 50.0),
#  (19, 50.0),
#  (20, 50.0),
#  (21, 50.0),
#  (23, 50.0),
#  (25, 50.0),
#  (26, 50.0),
#  (27, 50.0),
#  (28, 50.0),
#  (29, 50.0),
#  (30, 50.0),
#  (32, 50.0),
#  (33, 50.0),
#  (35, 50.0),
#  (36, 50.0),
#  (37, 50.0),
#  (38, 50.0),
#  (40, 50.0),
#  (41, 50.0),
#  (43, 50.0),
#  (45, 50.0),
#  (46, 50.0),
#  (47, 50.0),
#  (49, 50.0),
#  (50, 50.0),
#  (51, 50.0),
#  (53, 50.0),
#  (54, 50.0),
#  (55, 50.0),
#  (56, 50.0),
#  (57, 50.0),
#  (58, 50.0),
#  (59, 50.0),
#  (61, 50.0),
#  (62, 50.0),
#  (64, 50.0),
#  (65, 50.0),
#  (66, 50.0),
#  (67, 50.0),
#  (71, 50.0),
#  (72, 50.0),
#  (73, 50.0),
#  (76, 50.0),
#  (77, 50.0),
#  (78, 50.0),
#  (80, 50.0),
#  (81, 50.0),
#  (82, 50.0),
#  (83, 50.0),
#  (84, 50.0),
#  (85, 50.0),
#  (86, 50.0),
#  (88, 50.0),
#  (89, 50.0),
#  (90, 50.0),
#  (93, 50.0),
#  (94, 50.0),
#  (95, 50.0),
#  (96, 50.0),
#  (97, 50.0),
#  (98, 50.0),
#  (99, 50.0),
#  (100, 50.0)]

# %%
# Mengubah hasil sorted defuzzi menjadi dataframe agar bisa diubah ke file excel kembali
dfHasilAkhir = makeDataframeTopTen(sortedDefuziedDataset)
dfHasilAkhir
# Out:
#      ID  Hasil
# 0     3  100.0
# 1    13  100.0
# 2    15  100.0
# 3    16  100.0
# 4    24  100.0
# ..  ...    ...
# 95   96   50.0
# 96   97   50.0
# 97   98   50.0
# 98   99   50.0
# 99  100   50.0
#
# [100 rows x 2 columns]

# %%
# Membuat file excel dari dataframe top 10 (row 0 - 9)
dfHasilAkhir.head(10).to_excel("peringkat.xlsx")
